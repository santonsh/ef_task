# %%
import pandas as pd
import json
import numpy as np
import time

with open('data.json') as f:
    data = json.load(f)

# %matplotlib qt

# %%
# Reading to dataframe
# Creating additional columns
gen = ((k, v['assetA']['bid'], v['assetA']['ask'], v['assetB']['bid'], v['assetB']['ask']) for k, v in data.items())
data_list = [x for x in gen]
df = pd.DataFrame(data_list, columns=['timestamp', 'assetA_bid', 'assetA_ask', 'assetB_bid', 'assetB_ask'])
df['delta_t'] = df['timestamp'].astype('uint64').diff()
df['trade_freq'] = df.apply (lambda row: 1/row['delta_t'], axis=1)
df['trade_freq_avg'] = df['trade_freq'].rolling(window=15).mean()
df['ts'] = df['timestamp']
df = df.set_index('timestamp')

# %%
# Lets chart some analytics - trade frequency, tick frequency
import matplotlib.pyplot as plt

fig0, (ax00, ax01) = plt.subplots(2, 1)
ax00.set_title('Tick time delta histogram (up to 2 seconds)')
ax01.set_title('Tick time delta averaged in time')
df['delta_t'].hist(ax = ax00, bins = np.arange(10,2000,100))
df['delta_t'].rolling(window=30).mean().rolling(window=30).mean().rolling(window=30).mean().plot(ax = ax01)

# Conclutions:
# 1. the samples are highlty uneaven with rare time deltas up to several minutes. Most time deltas between the samples however are between 50 and 500 ms
# 2. Due to (1) several approaches can be taked to fight non uniformity of samples
#   a. upsample missing timepoints
#   b. craete new more uniform ticks by special transformation (time, volume, cumulative price ticks or entropy based ticks)
#   c. train predictor in such a way that accounts for timme deltas between samples
#   d. assume low impact of non uniformity and treat as uniform (probably a bad idea but will do for start)

# %%
# Plot the ask/bid data for analysis
# Get the timeline data 
start = df.iloc[[0]].index.astype('uint64')
end = df.iloc[[-1]].index.astype('uint64')
timedelta = end-start
print(f'The time period is: {timedelta/1000/60/60/24} days')
print(f'Maximum possible trades in this period is: {timedelta/1000/30} trades')

# Setting up the grids
delta_t = end.to_numpy()-start.to_numpy()
number_of_ticks = len(df)
minor_grid_min = 0.5
ticksPerHour = number_of_ticks/(delta_t/1000/60/60)
ticksPerMinorGrid = number_of_ticks/(delta_t/1000/60)*minor_grid_min

hour_grid = np.arange(-0.2*number_of_ticks, 1.2*number_of_ticks, ticksPerHour)
minor_grid = np.arange(-0.2*number_of_ticks, 1.2*number_of_ticks, ticksPerMinorGrid)

# Plot the next graphs:
# Subplot 1
# a. A spread
# b. B spread
# c. A ask and bid
# c. B ask and bid

SpreadA = df['assetA_ask'].sub(df['assetA_bid'])
SpreadB = df['assetB_ask'].sub(df['assetB_bid'])
bidA = df['assetA_bid']
askA = df['assetA_ask']
bidB = df['assetB_bid']
askB = df['assetB_ask']

fig1, (ax10, ax11, ax12) = plt.subplots(3, 1)
#ax10.set_xticks(hour_grid)
#ax10.set_xticks(minor_grid, minor=True)
#ax10.grid(which='both')

for sig in [bidA, askA, bidB, askB]:
    sig_scaled = sig-7050
    sig_scaled.plot(ax = ax10)
    sig_scaled.rolling(window=30).mean().plot(ax = ax10, style=':')

i = -20
for sig in [SpreadA, SpreadB]:
    i=i+20
    sig_scaled = sig*5+i # Just a scaling to fit on one axes
    sig_scaled.plot(ax = ax10)
    sig_scaled.rolling(window=30).mean().plot(ax = ax10, style=':')

ax10.legend(['bidA', 'bidA avg', 'askA', 'askA avg', 'bidB', 'bidB avg', 'askB', 'askB avg', 'SpreadA', 'SpreadA avg', 'SpreadB', 'SpreadB avg'])
ax10.set_title('A and B ask/bid and spread')

# Subplot 2
# a. A ask and bid zoomin

zoomin_range = np.arange(4000,5000,1)

for sig in [bidA, askA]:
    sig.iloc[zoomin_range].plot(ax = ax11)
    sig_mov = sig.rolling(window=30).mean()
    sig_mov.iloc[zoomin_range].plot(ax = ax11, style=':')
    sig.iloc[zoomin_range].plot(ax = ax11, style = '.')

ax11.legend(['bidA', 'bidA avg', 'bidA scatter', 'askA', 'askA avg', 'askA scatter'])
ax11.set_title('A Signals zoomin')

# Subplot 3
# a. B ask and bid zoomin 

for sig in [bidB, askB]:
    sig.iloc[zoomin_range].plot(ax = ax12)
    sig_mov = sig.rolling(window=30).mean()
    sig_mov.iloc[zoomin_range].plot(ax = ax12, style=':')
    sig.iloc[zoomin_range].plot(ax = ax12, style = '.')

ax12.legend(['bidB', 'bidB avg', 'bidB scatter', 'askB', 'askB avg', 'askB scatter'])
ax12.set_title('B Signals zoomin')

# Conclutions:
# 1. Zoomout: 
#   a. The trading dataframe is of one day aproximately
#   b. A and B are hightly correlated at least at low resolution
#   c. There are negative spreads in the data up to tens of seconds. Three of possible explanations are 
#       i. Bullish of Bearish trades beyond optimal opposite price point 
#       ii. missing data points/lags in an order book that creates opposite price optimization lag
#       iii. Lagging price correction 

# 2. Zoomin
#   a. Uneven sampling can be seen
#   b. A and B have different trading dynamics
#   c. A and B have different spread
#   d. A and B have different trading patterns
#   e. As a result of (b), (c), and (d) we can deduct different number of traders, hightly different volumes traded for assets A ndd B
# Out:
# The time period is: Float64Index([1.083294814814815], dtype='float64', name='timestamp') days
# Maximum possible trades in this period is: Float64Index([3119.889066666667], dtype='float64', name='timestamp') trades
# Text(0.5, 1.0, 'B Signals zoomin')

# %%
# Plot the ask/bid data analitics

fig2, (ax20, ax21, ax22) = plt.subplots(3, 1)

# Subplot 1
# a. A trailing window var
# b. B trailing window var

ax20.set_title('Rolling window signal variance')

i=0
for sig in [bidA, askA, bidB, askB]:
    i=i+10
    sig_mov = sig.rolling(window=30).var()+i
    sig_mov.plot(ax = ax20)

ax20.legend(['bidA var', 'askA var','bidB var', 'askB var'])
ax20.get_xaxis().set_visible(False)

# Subplot 2
# a. ask/bid trailing window cov

ax21.set_title('Rolling window ask/bid covariance')
cov_A = bidA.rolling(window=30).cov(other = askA)+10
cov_B = bidB.rolling(window=30).cov(other = askB)-10
cov_A.plot(ax = ax21)
cov_B.plot(ax = ax21)
ax21.legend(['A bid/ask cov', 'B bid/ask cov'])
ax21.get_xaxis().set_visible(False)

# Subplot 3
# a. AB trailing window cov

ax22.set_title('Rolling window A/B covariance')
cov_bid = bidA.rolling(window=30).cov(other = bidB)+10
cov_ask = askA.rolling(window=30).cov(other = askB)-10
cov_bid.plot(ax = ax22)
cov_ask.plot(ax = ax22)
ax22.legend(['A/B bid cov', 'A/B ask cov'])
ax22.get_xaxis().set_visible(False)

# Conclutions:
#   a. Hmmmm... Not sure what can be seen here at low resolution in regard of var/covar between signals. 
#   b. Peaks in A/B and bid/ask covariance correlates to occations of magor trading (volume, price change) likely (?)
#   c. var and covar graphs for all the signals look alike which probably reflect the fact that assets are closely related. Especially it shows at major trading periods (spikes in var/covar)

# %%
##################################################################
##################################################################
###############    Trading bot
##################################################################

# A simple trading system can be sketched as this:
# (A) marketInputs -> (B) features/signals -> (C) assetPredictions [t, price, prob] -> (D) portfolioOtimization -> (E) orders

# For (A) we have our initial signals

# For (B) we can generate new features like trading frequency, volume, signal variance. In general case this can include outside signals like semantic market analysis or other exchanges data. 

# For (C) possibilities are wast. The predictor can be short termed, long termed, tech analysis based, ML/NN based. In this assignment we will check 3 options for the predictor:
#   a. Ideal predictor. The predictor that knows the future exactly. Built by using existing dataframe. It is good for initial debug and as a performance reference for other predictors
#   b. overfitted NN predictor. We will train the NN on the entire dataframe and use it on the same dataframe in inference mode for trading. It is not a fair predictor as it uses information from the future for learning. However it can be used as a refeerence for future predictors
#   c. NN predictor that is trained on a past window and is used for some time until the model get updated with new data. 

# For (D) we will use a strategy that chooses to maximize predicted return on portfolio. For the sake of assignment we assume oreders of 1 only so we will not create risk-return optimized and distributed portfolios. In real world however it is a good idea to predict prices/signals/returns with probabilities and use them to maintain return-risk optimized portfolios be choosing assets to be close to efficiency frontier. 

# (E) Orders should be of size of one every time and spaced at least 30 seconds each


# Lets start!

# %%
def lookAheadTradeReturnPredictorFunc(pred, active_asset, N):
    # Input:
    #   Array of [K x 2N] (2 * trading delay) prices predictions for K assets
    # Output:
    #   [K x N] Array of minimal return predictions for each of next N ticks (1*trading delay delta) for each asset
    # Note: later to each element of future return predictions in non active asset the delta of active asset for the preceeding period should be added to account for a price of not taking a trading action 
    # Note: Each of the points in the array answers the question "what would be my return after minimal trading delay if I choose to go into asset k at timepoint 0<=n<N". Why so many optional point n instead of just a single time point in the present? Because by being gridy we are risking missing the "good" trade point in the nearest future because of the introduced trading delay   
    # A1 [1   2 3 1  3 1 3  4 4 23 32  32 34 ]
    # A2 [-1 -2 3 1 -3 1 3 -4 4 2  12 -12 14 ]
    # Note: How the trade return is calculated? At tick 0<=n<N asset price[buy/ask] (active asset is an exception) is taken and substracted from the sell/bid price at point n'=n+N (Next nearest possible trade)
    
    try:
        # first compute the return of active asset up to timepoint n if no decicion is made now at n=0
        if active_asset != -1 and active_asset < len(pred):
            bid = pred[active_asset][1]
            aa_ret_up_to_n = [bid[i]-bid[0] for i in range(0,N)]
        else:
            # no active asset means no return on it
            aa_ret_up_to_n = [0 for i in range(0,N)]

        returns = []
        for asset, data in enumerate(pred):
            [ask, bid] = data
            ret = []
            if asset == active_asset:
                for n in range(0,N):
                    r = bid[n+N] - bid[n] + aa_ret_up_to_n[n] # if asset is active then we dont have to buy it hence bid instead of ask
                    ret.append(r)
            else:
                for n in range(0,N):
                    r = bid[n+N] - ask[n] + aa_ret_up_to_n[n]
                    ret.append(r)
            returns.append(ret)
        return returns
    except: # in case of too short prediction vector for example
        return []

def lookAheadTradeDescitionMakerFunc(return_pred, greediness_w ):
    # Input:
    # [K x N] trading return predictions array
    # [N] Greediness vector. This is a vector that favors the earlier trades by multiplying the predicted returns vector for each asset. This is to caount for time value lost in delayed trades and rising uncertanty for farther predictions
    # Output:
    # (asset_idx, min_return) Returns index of asset with best predicted return and the predicted return itself 
    max_asset = -1
    max_return = 0
    max_time = 0
    for asset, ret in enumerate(return_pred):
        # weight the trading delay
        for i in range(len(ret)):
            ret[i] = ret[i]*greediness_w[i]
        # find the max for this asset return    
        m = max(ret)
        if m > max_return:
            max_return = m
            max_asset = asset
            max_time = ret.index(m)

    return (max_return, max_asset, max_time)

class idealPredictor():
    # This just looks into the future of dataframe
    def __init__(self, df, cols, lookahead):
        self.df = df
        self.lookahead = lookahead
        self.cols = cols
    
    def update(self, data):
        pass

    def predict(self, ts):
        try:
            its = df.index.get_loc(ts)
            sub_df = df.iloc[its:its+self.lookahead][self.cols]
            pred = []
            for c in self.cols:
                pred.append(sub_df[c].to_numpy())
            return pred
        except:
            return []

class tradingBot():
    # Note: 
    # Simple bot scheme
    # bare_signals -> features -> price_prediction  -> trade_orders  
    #                                     strategy  ->
    def __init__(self, asset_names, trading_delay, ticks_per_trade_delay, predictor, calcRetFunc, calcDescisionFunc ):
        self.last_trade = 0
        self.trading_delay = trading_delay 
        self.orders = []
        self.last_order = {}
        self.cur_asset_id = -1
        self.cur_qty = 0
        self.cur_ts = 0
        self.N = ticks_per_trade_delay
        self.predictor = predictor
        self.calcRetFunc = calcRetFunc
        self.calcDescisionFunc = calcDescisionFunc
        self.greediness_w = [1 for i in range(self.N)]
        self.last_data = []
        self.asset_names = asset_names

        
    def compute_tick(self, ts, data):
        # this handles new data arriving to the bot
        # done
        self.append_data(data)
        self.pred = self.predictor.update(data)
        self.cur_ts = ts
        # perform action if enough time passed since last action
        if (int(ts)-int(self.last_trade)) > self.trading_delay*1000:
            pred = self.predictor.predict(self.cur_ts)
            # convert prediction signals to ask/bid pairs list: [[askA, bidA], [askB, bidB]..... ]
            self.pred = [[pred[2*i], pred[2*i+1]] for i in range(int(len(pred)/2))]
            new_asset_id = self.compute_trade()
            self.update_state(new_asset_id)

    def append_data(self, data):
        # EXTEND LATER
        self.last_data = data
        #for asset, val in items(data):
        pass

    def compute_trade(self):
        # this computes trade based on the current market
        return_pred = self.calcRetFunc(self.pred, self.cur_asset_id, self.N)
        # kinda error handling - REFACTOR!!!
        if return_pred == []:
            return self.cur_asset_id
        (expected_ret, asset_id, trade_time) = self.calcDescisionFunc(return_pred, self.greediness_w)
        # if the optimum in the future skip the trade
        if trade_time>0:
            return self.cur_asset_id
        return asset_id

    def update_state(self, tgt_asset_id):
        # this updates bot state based on target asset_id
        # done
        tgt_asset_id = int(tgt_asset_id)
        if tgt_asset_id != self.cur_asset_id:
            if self.cur_asset_id == -1:
                self.issue_trades([('buy', tgt_asset_id)])
            elif tgt_asset_id == -1:
                self.issue_trades([('sell', self.cur_asset_id)])
            else:
                self.issue_trades([('sell', self.cur_asset_id), ('buy', tgt_asset_id)])
    
    def issue_trades(self, orders):
        # done
        actions = []
        for (order_type, asset_id) in orders:
            # update the quantities and asset stocks
            if order_type == 'sell':
                self.cur_qty = self.cur_qty*self.get_sell_price(asset_id)
                self.cur_asset_id = -1
            elif order_type == 'buy':
                self.cur_asset_id = asset_id
                self.cur_qty = self.cur_qty/self.get_buy_price(asset_id)
            # update the orders
            actions.append(order_type+self.asset_names[asset_id])
            
        # update an order book
        self.orders.append({
                "time": int(self.cur_ts),
                "actions": actions
                })
        self.last_trade = self.cur_ts

    def get_sell_price(self, asset_id):
        return self.last_data[asset_id]['bid']

    def get_buy_price(self, asset_id):
        return self.last_data[asset_id]['ask']
       
    def getOrderList(self):
        return self.orders

# %%
# Auxilary functions to run the bot
def read_tick(df):
    for i, row in df.iterrows():
        tick = {'timestamp':row['ts'],
                'assets':[  {'ask':row['assetA_ask'],'bid':row['assetA_bid']}, 
                            {'ask':row['assetB_ask'],'bid':row['assetB_bid']}
                        ]
                }
        yield tick



# Creating the bot
#df = df.iloc[0:5000]
ticks_per_trade_delay = 60
trade_delay = 30
asset_names = ['A', 'B']
idealP = idealPredictor(df, ['assetA_ask', 'assetA_bid', 'assetB_ask', 'assetB_bid'], ticks_per_trade_delay*2)
bot = tradingBot(asset_names, trade_delay, ticks_per_trade_delay, idealP, lookAheadTradeReturnPredictorFunc, lookAheadTradeDescitionMakerFunc)

# Running the simulation
i = 0
j = 0
total_kts = round(len(df)/1000)
start = time.time()
total_process_time = 0
for t in read_tick(df):
    i=i+1
    bot.compute_tick(t['timestamp'], t['assets'])
    if i == 1000:
        j=j+1
        end = time.time()
        delta = end-start
        total_process_time = total_process_time + delta
        avg_k_process_time = float(total_process_time)/j
        start = time.time()
        i = 0
        
        print(f'{j}/{total_kts}k timesamples are processed. It took {delta:.2f} seconds. Estimated time left is: {avg_k_process_time*(total_kts-j):.2f} seconds ')

print(f'Done! All {total_kts}k timesamples were processed')

output = bot.getOrderList()
# Out:
# : 116.45 seconds
# 8/214k tamesamples are processed. It took 0.83 seconds. Estimated time left is: 122.73 seconds
# 9/214k tamesamples are processed. It took 0.68 seconds. Estimated time left is: 124.01 seconds
# 10/214k tamesamples are processed. It took 1.04 seconds. Estimated time left is: 132.18 seconds
# 11/214k tamesamples are processed. It took 0.49 seconds. Estimated time left is: 128.68 seconds
# 12/214k tamesamples are processed. It took 0.61 seconds. Estimated time left is: 127.64 seconds
# 13/214k tamesamples are processed. It took 1.05 seconds. Estimated time left is: 133.47 seconds
# 14/214k tamesamples are processed. It took 0.71 seconds. Estimated time left is: 133.49 seconds
# 15/214k tamesamples are processed. It took 0.84 seconds. Estimated time left is: 135.12 seconds
# 16/214k tamesamples are processed. It took 0.51 seconds. Estimated time left is: 132.41 seconds
# 17/214k tamesamples are processed. It took 0.55 seconds. Estimated time left is: 130.32 seconds
# 18/214k tamesamples are processed. It took 0.49 seconds. Estimated time left is: 127.77 seconds
# 19/214k tamesamples are processed. It took 0.22 seconds. Estimated time left is: 122.70 seconds
# 20/214k tamesamples are processed. It took 0.41 seconds. Estimated time left is: 119.95 seconds
# 21/214k tamesamples are processed. It took 0.54 seconds. Estimated time left is: 118.57 seconds
# 22/214k tamesamples are processed. It took 0.83 seconds. Estimated time left is: 119.86 seconds
# 23/214k tamesamples are processed. It took 0.75 seconds. Estimated time left is: 120.27 seconds
# 24/214k tamesamples are processed. It took 0.73 seconds. Estimated time left is: 120.42 seconds
# 25/214k tamesamples are processed. It took 0.71 seconds. Estimated time left is: 120.37 seconds
# 26/214k tamesamples are processed. It took 0.63 seconds. Estimated time left is: 119.71 seconds
# 27/214k tamesamples are processed. It took 0.63 seconds. Estimated time left is: 119.01 seconds
# 28/214k tamesamples are processed. It took 0.75 seconds. Estimated time left is: 119.12 seconds
# 29/214k tamesamples are processed. It took 0.65 seconds. Estimated time left is: 118.52 seconds
# 30/214k tamesamples are processed. It took 0.41 seconds. Estimated time left is: 116.46 seconds
# 31/214k tamesamples are processed. It took 0.41 seconds. Estimated time left is: 114.52 seconds
# 32/214k tamesamples are processed. It took 0.50 seconds. Estimated time left is: 113.19 seconds
# 33/214k tamesamples are processed. It took 0.46 seconds. Estimated time left is: 111.67 seconds
# 34/214k tamesamples are processed. It took 0.95 seconds. Estimated time left is: 112.81 seconds
# 35/214k tamesamples are processed. It took 0.45 seconds. Estimated time left is: 111.26 seconds
# 36/214k tamesamples are processed. It took 0.88 seconds. Estimated time left is: 111.93 seconds
# 37/214k tamesamples are processed. It took 0.67 seconds. Estimated time left is: 111.49 seconds
# 38/214k tamesamples are processed. It took 0.83 seconds. Estimated time left is: 111.79 seconds
# 39/214k tamesamples are processed. It took 0.68 seconds. Estimated time left is: 111.34 seconds
# 40/214k tamesamples are processed. It took 0.69 seconds. Estimated time left is: 110.92 seconds
# 41/214k tamesamples are processed. It took 1.08 seconds. Estimated time left is: 112.15 seconds
# 42/214k tamesamples are processed. It took 0.58 seconds. Estimated time left is: 111.21 seconds
# 43/214k tamesamples are processed. It took 0.76 seconds. Estimated time left is: 111.01 seconds
# 44/214k tamesamples are processed. It took 0.71 seconds. Estimated time left is: 110.59 seconds
# 45/214k tamesamples are processed. It took 0.54 seconds. Estimated time left is: 109.54 seconds
# 46/214k tamesamples are processed. It took 0.72 seconds. Estimated time left is: 109.17 seconds
# 47/214k tamesamples are processed. It took 0.58 seconds. Estimated time left is: 108.25 seconds
# 48/214k tamesamples are processed. It took 0.35 seconds. Estimated time left is: 106.58 seconds
# 49/214k tamesamples are processed. It took 0.83 seconds. Estimated time left is: 106.56 seconds
# 50/214k tamesamples are processed. It took 0.91 seconds. Estimated time left is: 106.79 seconds
# 51/214k tamesamples are processed. It took 0.56 seconds. Estimated time left is: 105.85 seconds
# 52/214k tamesamples are processed. It took 1.07 seconds. Estimated time left is: 106.50 seconds
# 53/214k tamesamples are processed. It took 0.72 seconds. Estimated time left is: 106.02 seconds
# 54/214k tamesamples are processed. It took 0.77 seconds. Estimated time left is: 105.70 seconds
# 55/214k tamesamples are processed. It took 0.80 seconds. Estimated time left is: 105.44 seconds
# 56/214k tamesamples are processed. It took 1.14 seconds. Estimated time left is: 106.13 seconds
# 57/214k tamesamples are processed. It took 1.17 seconds. Estimated time left is: 106.84 seconds
# 58/214k tamesamples are processed. It took 0.71 seconds. Estimated time left is: 106.23 seconds
# 59/214k tamesamples are processed. It took 0.92 seconds. Estimated time left is: 106.19 seconds
# 60/214k tamesamples are processed. It took 0.69 seconds. Estimated time left is: 105.51 seconds
# 61/214k tamesamples are processed. It took 0.95 seconds. Estimated time left is: 105.48 seconds
# 62/214k tamesamples are processed. It took 0.69 seconds. Estimated time left is: 104.79 seconds
# 63/214k tamesamples are processed. It took 0.43 seconds. Estimated time left is: 103.47 seconds
# 64/214k tamesamples are processed. It took 1.02 seconds. Estimated time left is: 103.57 seconds
# 65/214k tamesamples are processed. It took 0.79 seconds. Estimated time left is: 103.10 seconds
# 66/214k tamesamples are processed. It took 1.23 seconds. Estimated time left is: 103.61 seconds
# 67/214k tamesamples are processed. It took 1.13 seconds. Estimated time left is: 103.86 seconds
# 68/214k tamesamples are processed. It took 1.16 seconds. Estimated time left is: 104.13 seconds
# 69/214k tamesamples are processed. It took 0.37 seconds. Estimated time left is: 102.69 seconds
# 70/214k tamesamples are processed. It took 0.36 seconds. Estimated time left is: 101.27 seconds
# 71/214k tamesamples are processed. It took 0.48 seconds. Estimated time left is: 100.11 seconds
# 72/214k tamesamples are processed. It took 0.78 seconds. Estimated time left is: 99.56 seconds
# 73/214k tamesamples are processed. It took 0.47 seconds. Estimated time left is: 98.42 seconds
# 74/214k tamesamples are processed. It took 0.76 seconds. Estimated time left is: 97.84 seconds
# 75/214k tamesamples are processed. It took 0.39 seconds. Estimated time left is: 96.57 seconds
# 76/214k tamesamples are processed. It took 0.24 seconds. Estimated time left is: 95.04 seconds
# 77/214k tamesamples are processed. It took 0.39 seconds. Estimated time left is: 93.83 seconds
# 78/214k tamesamples are processed. It took 0.96 seconds. Estimated time left is: 93.62 seconds
# 79/214k tamesamples are processed. It took 0.79 seconds. Estimated time left is: 93.11 seconds
# 80/214k tamesamples are processed. It took 0.85 seconds. Estimated time left is: 92.68 seconds
# 81/214k tamesamples are processed. It took 0.41 seconds. Estimated time left is: 91.53 seconds
# 82/214k tamesamples are processed. It took 0.75 seconds. Estimated time left is: 90.94 seconds
# 83/214k tamesamples are processed. It took 0.70 seconds. Estimated time left is: 90.27 seconds
# 84/214k tamesamples are processed. It took 0.27 seconds. Estimated time left is: 88.93 seconds
# 85/214k tamesamples are processed. It took 0.73 seconds. Estimated time left is: 88.32 seconds
# 86/214k tamesamples are processed. It took 0.90 seconds. Estimated time left is: 87.95 seconds
# 87/214k tamesamples are processed. It took 0.83 seconds. Estimated time left is: 87.48 seconds
# 88/214k tamesamples are processed. It took 1.02 seconds. Estimated time left is: 87.26 seconds
# 89/214k tamesamples are processed. It took 0.93 seconds. Estimated time left is: 86.91 seconds
# 90/214k tamesamples are processed. It took 0.79 seconds. Estimated time left is: 86.34 seconds
# 91/214k tamesamples are processed. It took 0.93 seconds. Estimated time left is: 85.96 seconds
# 92/214k tamesamples are processed. It took 1.05 seconds. Estimated time left is: 85.73 seconds
# 93/214k tamesamples are processed. It took 0.96 seconds. Estimated time left is: 85.36 seconds
# 94/214k tamesamples are processed. It took 0.93 seconds. Estimated time left is: 84.93 seconds
# 95/214k tamesamples are processed. It took 1.18 seconds. Estimated time left is: 84.81 seconds
# 96/214k tamesamples are processed. It took 1.32 seconds. Estimated time left is: 84.85 seconds
# 97/214k tamesamples are processed. It took 0.96 seconds. Estimated time left is: 84.43 seconds
# 98/214k tamesamples are processed. It took 0.30 seconds. Estimated time left is: 83.21 seconds
# 99/214k tamesamples are processed. It took 0.32 seconds. Estimated time left is: 82.03 seconds
# 100/214k tamesamples are processed. It took 0.50 seconds. Estimated time left is: 81.08 seconds
# 101/214k tamesamples are processed. It took 0.86 seconds. Estimated time left is: 80.53 seconds
# 102/214k tamesamples are processed. It took 0.70 seconds. Estimated time left is: 79.81 seconds
# 103/214k tamesamples are processed. It took 0.66 seconds. Estimated time left is: 79.04 seconds
# 104/214k tamesamples are processed. It took 0.37 seconds. Estimated time left is: 77.97 seconds
# 105/214k tamesamples are processed. It took 0.58 seconds. Estimated time left is: 77.13 seconds
# 106/214k tamesamples are processed. It took 1.15 seconds. Estimated time left is: 76.87 seconds
# 107/214k tamesamples are processed. It took 0.85 seconds. Estimated time left is: 76.29 seconds
# 108/214k tamesamples are processed. It took 0.65 seconds. Estimated time left is: 75.52 seconds
# 109/214k tamesamples are processed. It took 0.63 seconds. Estimated time left is: 74.72 seconds
# 110/214k tamesamples are processed. It took 0.57 seconds. Estimated time left is: 73.88 seconds
# 111/214k tamesamples are processed. It took 0.74 seconds. Estimated time left is: 73.20 seconds
# 112/214k tamesamples are processed. It took 0.95 seconds. Estimated time left is: 72.71 seconds
# 113/214k tamesamples are processed. It took 0.70 seconds. Estimated time left is: 71.99 seconds
# 114/214k tamesamples are processed. It took 0.79 seconds. Estimated time left is: 71.34 seconds
# 115/214k tamesamples are processed. It took 0.58 seconds. Estimated time left is: 70.52 seconds
# 116/214k tamesamples are processed. It took 0.70 seconds. Estimated time left is: 69.80 seconds
# 117/214k tamesamples are processed. It took 1.01 seconds. Estimated time left is: 69.33 seconds
# 118/214k tamesamples are processed. It took 0.82 seconds. Estimated time left is: 68.70 seconds
# 119/214k tamesamples are processed. It took 1.45 seconds. Estimated time left is: 68.58 seconds
# 120/214k tamesamples are processed. It took 0.72 seconds. Estimated time left is: 67.85 seconds
# 121/214k tamesamples are processed. It took 0.61 seconds. Estimated time left is: 67.04 seconds
# 122/214k tamesamples are processed. It took 0.75 seconds. Estimated time left is: 66.34 seconds
# 123/214k tamesamples are processed. It took 0.74 seconds. Estimated time left is: 65.64 seconds
# 124/214k tamesamples are processed. It took 0.72 seconds. Estimated time left is: 64.92 seconds
# 125/214k tamesamples are processed. It took 0.59 seconds. Estimated time left is: 64.10 seconds
# 126/214k tamesamples are processed. It took 1.28 seconds. Estimated time left is: 63.77 seconds
# 127/214k tamesamples are processed. It took 1.01 seconds. Estimated time left is: 63.24 seconds
# 128/214k tamesamples are processed. It took 1.17 seconds. Estimated time left is: 62.81 seconds
# 129/214k tamesamples are processed. It took 0.79 seconds. Estimated time left is: 62.12 seconds
# 130/214k tamesamples are processed. It took 0.49 seconds. Estimated time left is: 61.23 seconds
# 131/214k tamesamples are processed. It took 0.65 seconds. Estimated time left is: 60.45 seconds
# 132/214k tamesamples are processed. It took 1.09 seconds. Estimated time left is: 59.95 seconds
# 133/214k tamesamples are processed. It took 1.33 seconds. Estimated time left is: 59.58 seconds
# 134/214k tamesamples are processed. It took 1.11 seconds. Estimated time left is: 59.07 seconds
# 135/214k tamesamples are processed. It took 0.87 seconds. Estimated time left is: 58.41 seconds
# 136/214k tamesamples are processed. It took 0.82 seconds. Estimated time left is: 57.72 seconds
# 137/214k tamesamples are processed. It took 0.59 seconds. Estimated time left is: 56.89 seconds
# 138/214k tamesamples are processed. It took 0.50 seconds. Estimated time left is: 56.02 seconds
# 139/214k tamesamples are processed. It took 0.34 seconds. Estimated time left is: 55.07 seconds
# 140/214k tamesamples are processed. It took 0.71 seconds. Estimated time left is: 54.32 seconds
# 141/214k tamesamples are processed. It took 0.87 seconds. Estimated time left is: 53.66 seconds
# 142/214k tamesamples are processed. It took 0.72 seconds. Estimated time left is: 52.91 seconds
# 143/214k tamesamples are processed. It took 1.04 seconds. Estimated time left is: 52.33 seconds
# 144/214k tamesamples are processed. It took 1.19 seconds. Estimated time left is: 51.81 seconds
# 145/214k tamesamples are processed. It took 0.85 seconds. Estimated time left is: 51.12 seconds
# 146/214k tamesamples are processed. It took 1.02 seconds. Estimated time left is: 50.51 seconds
# 147/214k tamesamples are processed. It took 1.09 seconds. Estimated time left is: 49.93 seconds
# 148/214k tamesamples are processed. It took 0.94 seconds. Estimated time left is: 49.27 seconds
# 149/214k tamesamples are processed. It took 1.33 seconds. Estimated time left is: 48.78 seconds
# 150/214k tamesamples are processed. It took 0.52 seconds. Estimated time left is: 47.93 seconds
# 151/214k tamesamples are processed. It took 0.45 seconds. Estimated time left is: 47.05 seconds
# 152/214k tamesamples are processed. It took 0.69 seconds. Estimated time left is: 46.28 seconds
# 153/214k tamesamples are processed. It took 1.12 seconds. Estimated time left is: 45.68 seconds
# 154/214k tamesamples are processed. It took 0.66 seconds. Estimated time left is: 44.90 seconds
# 155/214k tamesamples are processed. It took 0.63 seconds. Estimated time left is: 44.11 seconds
# 156/214k tamesamples are processed. It took 0.57 seconds. Estimated time left is: 43.29 seconds
# 157/214k tamesamples are processed. It took 0.60 seconds. Estimated time left is: 42.49 seconds
# 158/214k tamesamples are processed. It took 0.93 seconds. Estimated time left is: 41.82 seconds
# 159/214k tamesamples are processed. It took 0.94 seconds. Estimated time left is: 41.14 seconds
# 160/214k tamesamples are processed. It took 0.79 seconds. Estimated time left is: 40.40 seconds
# 161/214k tamesamples are processed. It took 0.72 seconds. Estimated time left is: 39.64 seconds
# 162/214k tamesamples are processed. It took 1.23 seconds. Estimated time left is: 39.05 seconds
# 163/214k tamesamples are processed. It took 1.21 seconds. Estimated time left is: 38.44 seconds
# 164/214k tamesamples are processed. It took 1.03 seconds. Estimated time left is: 37.77 seconds
# 165/214k tamesamples are processed. It took 0.82 seconds. Estimated time left is: 37.04 seconds
# 166/214k tamesamples are processed. It took 0.87 seconds. Estimated time left is: 36.31 seconds
# 167/214k tamesamples are processed. It took 0.92 seconds. Estimated time left is: 35.60 seconds
# 168/214k tamesamples are processed. It took 0.81 seconds. Estimated time left is: 34.86 seconds
# 169/214k tamesamples are processed. It took 1.00 seconds. Estimated time left is: 34.17 seconds
# 170/214k tamesamples are processed. It took 1.10 seconds. Estimated time left is: 33.50 seconds
# 171/214k tamesamples are processed. It took 0.86 seconds. Estimated time left is: 32.76 seconds
# 172/214k tamesamples are processed. It took 0.78 seconds. Estimated time left is: 32.00 seconds
# 173/214k tamesamples are processed. It took 0.72 seconds. Estimated time left is: 31.23 seconds
# 174/214k tamesamples are processed. It took 0.88 seconds. Estimated time left is: 30.50 seconds
# 175/214k tamesamples are processed. It took 0.58 seconds. Estimated time left is: 29.69 seconds
# 176/214k tamesamples are processed. It took 0.89 seconds. Estimated time left is: 28.96 seconds
# 177/214k tamesamples are processed. It took 1.09 seconds. Estimated time left is: 28.27 seconds
# 178/214k tamesamples are processed. It took 1.00 seconds. Estimated time left is: 27.55 seconds
# 179/214k tamesamples are processed. It took 0.98 seconds. Estimated time left is: 26.83 seconds
# 180/214k tamesamples are processed. It took 1.15 seconds. Estimated time left is: 26.13 seconds
# 181/214k tamesamples are processed. It took 1.12 seconds. Estimated time left is: 25.43 seconds
# 182/214k tamesamples are processed. It took 0.97 seconds. Estimated time left is: 24.69 seconds
# 183/214k tamesamples are processed. It took 0.89 seconds. Estimated time left is: 23.94 seconds
# 184/214k tamesamples are processed. It took 0.81 seconds. Estimated time left is: 23.18 seconds
# 185/214k tamesamples are processed. It took 0.97 seconds. Estimated time left is: 22.43 seconds
# 186/214k tamesamples are processed. It took 0.88 seconds. Estimated time left is: 21.68 seconds
# 187/214k tamesamples are processed. It took 0.93 seconds. Estimated time left is: 20.93 seconds
# 188/214k tamesamples are processed. It took 0.80 seconds. Estimated time left is: 20.15 seconds
# 189/214k tamesamples are processed. It took 0.86 seconds. Estimated time left is: 19.39 seconds
# 190/214k tamesamples are processed. It took 0.48 seconds. Estimated time left is: 18.58 seconds
# 191/214k tamesamples are processed. It took 0.57 seconds. Estimated time left is: 17.78 seconds
# 192/214k tamesamples are processed. It took 0.96 seconds. Estimated time left is: 17.03 seconds
# 193/214k tamesamples are processed. It took 0.75 seconds. Estimated time left is: 16.25 seconds
# 194/214k tamesamples are processed. It took 1.29 seconds. Estimated time left is: 15.53 seconds
# 195/214k tamesamples are processed. It took 0.61 seconds. Estimated time left is: 14.74 seconds
# 196/214k tamesamples are processed. It took 0.98 seconds. Estimated time left is: 13.98 seconds
# 197/214k tamesamples are processed. It took 0.69 seconds. Estimated time left is: 13.20 seconds
# 198/214k tamesamples are processed. It took 0.75 seconds. Estimated time left is: 12.42 seconds
# 199/214k tamesamples are processed. It took 0.36 seconds. Estimated time left is: 11.61 seconds
# 200/214k tamesamples are processed. It took 1.10 seconds. Estimated time left is: 10.86 seconds
# 201/214k tamesamples are processed. It took 1.15 seconds. Estimated time left is: 10.11 seconds
# 202/214k tamesamples are processed. It took 0.74 seconds. Estimated time left is: 9.33 seconds
# 203/214k tamesamples are processed. It took 0.57 seconds. Estimated time left is: 8.54 seconds
# 204/214k tamesamples are processed. It took 0.69 seconds. Estimated time left is: 7.76 seconds
# 205/214k tamesamples are processed. It took 1.07 seconds. Estimated time left is: 7.00 seconds
# 206/214k tamesamples are processed. It took 1.27 seconds. Estimated time left is: 6.24 seconds
# 207/214k tamesamples are processed. It took 0.97 seconds. Estimated time left is: 5.46 seconds
# 208/214k tamesamples are processed. It took 0.87 seconds. Estimated time left is: 4.69 seconds
# 209/214k tamesamples are processed. It took 0.69 seconds. Estimated time left is: 3.90 seconds
# 210/214k tamesamples are processed. It took 1.05 seconds. Estimated time left is: 3.13 seconds
# 211/214k tamesamples are processed. It took 0.64 seconds. Estimated time left is: 2.34 seconds
# 212/214k tamesamples are processed. It took 0.97 seconds. Estimated time left is: 1.56 seconds
# 213/214k tamesamples are processed. It took 0.88 seconds. Estimated time left is: 0.78 seconds
# Done! All 214k tamesamples were processed

# %%
#print(output)

import json
with open('output.json', 'w') as fp:
    json.dump(output, fp)
