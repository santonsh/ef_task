# %%
import requests
import io
import os
import re
from bs4 import BeautifulSoup
import pandas as pd
urls = ['https://fbref.com/en/squads/a2d435b3/Leicester-City', 'https://fbref.com/en/squads/47c64c55/Crystal-Palace', 'https://fbref.com/en/squads/822bd0ba/Liverpool', 'https://fbref.com/en/squads/b8fd03ef/Manchester-City', 'https://fbref.com/en/squads/cff3d9bb/Chelsea', 'https://fbref.com/en/squads/19538871/Manchester-United', 'https://fbref.com/en/squads/8cec06e1/Wolverhampton-Wanderers', 'https://fbref.com/en/squads/1df6b87e/Sheffield-United', 'https://fbref.com/en/squads/361ca564/Tottenham-Hotspur', 'https://fbref.com/en/squads/18bb7c10/Arsenal', 'https://fbref.com/en/squads/943e8050/Burnley', 'https://fbref.com/en/squads/d3fd31cc/Everton', 'https://fbref.com/en/squads/b2b47a98/Newcastle-United', 'https://fbref.com/en/squads/33c895d4/Southampton', 'https://fbref.com/en/squads/d07537b9/Brighton--Hove-Albion', 'https://fbref.com/en/squads/7c21e445/West-Ham-United', 'https://fbref.com/en/squads/2abfe087/Watford', 'https://fbref.com/en/squads/4ba7cbea/Bournemouth', 'https://fbref.com/en/squads/8602292d/Aston-Villa', 'https://fbref.com/en/squads/1c781004/Norwich-City']
os.mkdir('PlayerData')

# %%
for url in urls:
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    table = soup.find_all('table', id = 'stats_standard_3232')
    table = table[0]
    teamname = url[37:]
    for row in table.find_all('tr'):
        position = row.find_all("td", {"data-stat" : "position"})
        for pos in position:
            if (pos.text == 'FW'):
                playername = row.find("th", {"data-stat" : "player"}).text
                url2 = 'https://fbref.com'+row.find_all('a', attrs={'href': re.compile("/en/players")})[1].get('href')
                csv_filename = teamname+'-'+playername + '.csv'
                txt_filename = playername + '.txt'
    
                response2 = requests.get(url2)
                #print(url2)
                soup2 = BeautifulSoup(response2.content, 'html.parser')
                table2 = soup2.find_all('table', id = 'matchlogs_all')
                table2 = table2[0]
                #print(table2)
            
                with io.open (txt_filename, 'w', encoding="utf-8") as r:
                    r.write('Day,Round,Venue,Result,Squad,Opponent,Start,Pos,Min,Gls,Ast,PK,PKatt,Sh,SoT,CrdY,CrdR,Touches,Press,Tkl,Int,Blocks,xG,npxG,xA,SCA,GCA,Cmp,Att,Cmp%,PassPrgDist,Carries,CarryPrgDist,Succ,DribAtt,Match Report,')
                    r.write('\n')
                    
                    for row2 in table2.find_all('tr')[:-1]:
                        for cell2 in row2.find_all('td'):
                            #print(cell2)
                            l = len(row2.find_all('td'))
                            #print(l)
                            if (l != 37):
                                continue
                            if (cell2.text.find(',') >= 0):
                                r.write(cell2.text.replace(',',' '))
                            else:
                                r.write(cell2.text)
                                #print(cell2.text)
                        
                            r.write(',')
                        r.write('\n')
                    
                    
                df = pd.read_csv(txt_filename)
                df.to_csv('PlayerData/'+csv_filename, index=None)
# Out:
# ht" data-stat="dribbles">4</td>
# <td class="left group_start" data-stat="match_report"><a href="/en/matches/4572cd0e/Manchester-City-Crystal-Palace-January-18-2020-Premier-League">Match Report</a></td>
# <td class="left" csk="3" data-stat="dayofweek">Tue</td>
# <td class="left" data-stat="comp"><a href="/en/comps/9/Premier-League-Stats">Premier League</a></td>
# <td class="left" data-stat="round"><a href="/en/comps/9/Premier-League-Stats">Matchweek 24</a></td>
# <td class="left" data-stat="venue">Home</td>
# <td class="center" csk="-2" data-stat="result" style="color:red; font-weight: bold;">L 0–2</td>
# <td class="left" data-stat="squad"><a href="/en/squads/47c64c55/Crystal-Palace-Stats">Crystal Palace</a></td>
# <td class="left" data-stat="opponent"><a href="/en/squads/33c895d4/Southampton-Stats">Southampton</a></td>
# <td class="center" csk="1" data-stat="game_started">Y</td>
# <td class="center" data-stat="position">FW</td>
# <td class="right" data-stat="minutes">68</td>
# <td class="right iz group_start" data-stat="goals">0</td>
# <td class="right iz" data-stat="assists">0</td>
# <td class="right iz" data-stat="pens_made">0</td>
# <td class="right iz" data-stat="pens_att">0</td>
# <td class="right" data-stat="shots_total">2</td>
# <td class="right iz" data-stat="shots_on_target">0</td>
# <td class="right iz" data-stat="cards_yellow">0</td>
# <td class="right iz" data-stat="cards_red">0</td>
# <td class="right" data-stat="touches">14</td>
# <td class="right" data-stat="pressures">19</td>
# <td class="right iz" data-stat="tackles">0</td>
# <td class="right iz" data-stat="interceptions">0</td>
# <td class="right iz" data-stat="blocks">0</td>
# <td class="right group_start" data-stat="xg">0.3</td>
# <td class="right" data-stat="npxg">0.3</td>
# <td class="right" data-stat="xa">0.0</td>
# <td class="right iz group_start" data-stat="sca">0</td>
# <td class="right iz" data-stat="gca">0</td>
# <td class="right group_start" data-stat="passes_completed">5</td>
# <td class="right" data-stat="passes">11</td>
# <td class="right" data-stat="passes_pct">45.5</td>
# <td class="right" data-stat="passes_progressive_distance">16</td>
# <td class="right group_start" data-stat="carries">10</td>
# <td class="right" data-stat="carry_progressive_distance">35</td>
# <td class="right group_start" data-stat="dribbles_completed">1</td>
# <td class="right" data-stat="dribbles">1</td>
# <td class="left group_start" data-stat="match_report"><a href="/en/matches/003ce1e3/Crystal-Palace-Southampton-January-21-2020-Premier-League">Match Report</a></td>
# <td class="left iz" data-stat="dayofweek"></td>
# <td class="left iz" data-stat="comp"></td>
# <td class="left iz" data-stat="round"></td>
# <td class="left iz" data-stat="venue"></td>
# <td class="center iz" data-stat="result"></td>
# <td class="left iz" data-stat="squad"></td>
# <td class="left iz" data-stat="opponent"></td>
# <td class="center iz" data-stat="game_started"></td>
# <td class="left iz" colspan="28" data-stat="bench_explain"></td>
# <td class="left iz group_start" data-stat="match_report"></td>
# <td class="left" csk="7" data-stat="dayofweek">Sat</td>
# <td class="left" data-stat="comp"><a href="/en/comps/9/Premier-League-Stats">Premier League</a></td>
# <td class="left" data-stat="round"><a href="/en/comps/9/Premier-League-Stats">Matchweek 27</a></td>
# <td class="left" data-stat="venue">Home</td>
# <td class="center" csk="1" data-stat="result" style="color:green; font-weight: bold;">W 1–0</td>
# <td class="left" data-stat="squad"><a href="/en/squads/47c64c55/Crystal-Palace-Stats">Crystal Palace</a></td>
# <td class="left" data-stat="opponent"><a href="/en/squads/b2b47a98/Newcastle-United-Stats">Newcastle Utd</a></td>
# <td class="center" csk="0" data-stat="game_started">N</td>
# <td class="center" data-stat="position">FW</td>
# <td class="right" data-stat="minutes">2</td>
# <td class="right iz group_start" data-stat="goals">0</td>
# <td class="right iz" data-stat="assists">0</td>
# <td class="right iz" data-stat="pens_made">0</td>
# <td class="right iz" data-stat="pens_att">0</td>
# <td class="right iz" data-stat="shots_total">0</td>
# <td class="right iz" data-stat="shots_on_target">0</td>
# <td class="right iz" data-stat="cards_yellow">0</td>
# <td class="right iz" data-stat="cards_red">0</td>
# <td class="right" data-stat="touches">5</td>
# <td class="right" data-stat="pressures">2</td>
# <td class="right" data-stat="tackles">1</td>
# <td class="right iz" data-stat="interceptions">0</td>
# <td class="right iz" data-stat="blocks">0</td>
# <td class="right group_start" data-stat="xg">0.0</td>
# <td class="right" data-stat="npxg">0.0</td>
# <td class="right" data-stat="xa">0.0</td>
# <td class="right iz group_start" data-stat="sca">0</td>
# <td class="right iz" data-stat="gca">0</td>
# <td class="right group_start" data-stat="passes_completed">2</td>
# <td class="right" data-stat="passes">2</td>
# <td class="right" data-stat="passes_pct">100.0</td>
# <td class="right" data-stat="passes_progressive_distance">8</td>
# <td class="right group_start" data-stat="carries">3</td>
# <td class="right" data-stat="carry_progressive_distance">2</td>
# <td class="right group_start" data-stat="dribbles_completed">1</td>
# <td class="right" data-stat="dribbles">1</td>
# <td class="left group_start" data-stat="match_report"><a href="/en/matches/5947b8fb/Crystal-Palace-Newcastle-United-February-22-2020-Premier-League">Match Report</a></td>
# <td class="left" csk="7" data-stat="dayofweek">Sat</td>
# <td class="left" data-stat="comp"><a href="/en/comps/9/Premier-League-Stats">Premier League</a></td>
# <td class="left" data-stat="round"><a href="/en/comps/9/Premier-League-Stats">Matchweek 28</a></td>
# <td class="left" data-stat="venue">Away</td>
# <td class="center" csk="1" data-stat="result" style="color:green; font-weight: bold;">W 1–0</td>
# <td class="left" data-stat="squad"><a href="/en/squads/47c64c55/Crystal-Palace-Stats">Crystal Palace</a></td>
# <td class="left" data-stat="opponent"><a href="/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats">Brighton</a></td>
# <td class="center" csk="0" data-stat="game_started">N</td>
# <td class="center" data-stat="position">FW</td>
# <td class="right" data-stat="minutes">4</td>
# <td class="right iz group_start" data-stat="goals">0</td>
# <td class="right iz" data-stat="assists">0</td>
# <td class="right iz" data-stat="pens_made">0</td>
# <td class="right iz" data-stat="pens_att">0</td>
# <td class="right iz" data-stat="shots_total">0</td>
# <td class="right iz" data-stat="shots_on_target">0</td>
# <td class="right iz" data-stat="cards_yellow">0</td>
# <td class="right iz" data-stat="cards_red">0</td>
# <td class="right" data-stat="touches">4</td>
# <td class="right" data-stat="pressures">7</td>
# <td class="right iz" data-stat="tackles">0</td>
# <td class="right iz" data-stat="interceptions">0</td>
# <td class="right iz" data-stat="blocks">0</td>
# <td class="right group_start" data-stat="xg">0.0</td>
# <td class="right" data-stat="npxg">0.0</td>
# <td class="right" data-stat="xa">0.0</td>
# <td class="right group_start" data-stat="sca">1</td>
# <td class="right iz" data-stat="gca">0</td>
# <td class="right group_start" data-stat="passes_completed">1</td>
# <td class="right" data-stat="passes">1</td>
# <td class="right" data-stat="passes_pct">100.0</td>
# <td class="right" data-stat="passes_progressive_distance">14</td>
# <td class="right group_start" data-stat="carries">4</td>
# <td class="right" data-stat="carry_progressive_distance">52</td>
# <td class="right group_start" data-stat="dribbles_completed">1</td>
# <td class="right" data-stat="dribbles">2</td>
# <td class="left group_start" data-stat="match_report"><a href="/en/matches/aeb979e2/Brighton-and-Hove-Albion-Crystal-Palace-February-29-2020-Premier-League">Match Report</a></td>
# <td class="left" csk="7" data-stat="dayofweek">Sat</td>
# <td class="left" data-stat="comp"><a href="/en/comps/9/Premier-League-Stats">Premier League</a></td>
# <td class="left" data-stat="round"><a href="/en/comps/9/Premier-League-Stats">Matchweek 18</a></td>
# <td class="left" data-stat="venue">Away</td>
# <td class="center" csk="-1" data-stat="result" style="color:red; font-weight: bold;">L 0–1</td>
# <td class="left" data-stat="squad"><a href="/en/squads/47c64c55/Crystal-Palace-Stats">Crystal Palace</a></td>
# <td class="left" data-stat="opponent"><a href="/en/squads/b2b47a98/Newcastle-United-Stats">Newcastle Utd</a></td>
# <td class="center" csk="-1" data-stat="game_started">N</td>
# <td class="left" colspan="19" data-stat="bench_explain">On matchday squad, but did not play</td>
# <td class="left group_start" data-stat="match_report"><a href="/en/matches/5e599d06/Newcastle-United-Crystal-Palace-December-21-2019-Premier-League">Match Report</a></td>
# <td class="left iz" data-stat="dayofweek"></td>
# <td class="left iz" data-stat="comp"></td>
# <td class="left iz" data-stat="round"></td>
# <td class="left iz" data-stat="venue"></td>
# <td class="center iz" data-stat="result"></td>
# <td class="left iz" data-stat="squad"></td>
# <td class="left iz" data-stat="opponent"></td>
# <td class="center iz" data-stat="game_started"></td>
# <td class="left iz" colspan="19" data-stat="bench_explain"></td>
# <td class="left iz group_start" data-stat="match_report"></td>
# <td class="left" csk="7" data-stat="dayofweek">Sat</td>
# <td class="left" data-stat="comp"><a href="/en/comps/9/Premier-League-Stats">Premier League</a></td>
# <td class="left" data-stat="round"><a href="/en/comps/9/Premier-League-Stats">Matchweek 20</a></td>
# <td class="left" data-stat="venue">Away</td>
# <td class="center" csk="0" data-stat="result" style="color:blue; font-weight: bold;">D 1–1</td>
# <td class="left" data-stat="squad"><a href="/en/squads/47c64c55/Crystal-Palace-Stats">Crystal Palace</a></td>
# <td class="left" data-stat="opponent"><a href="/en/squads/33c895d4/Southampton-Stats">Southampton</a></td>
# <td class="center" csk="-1" data-stat="game_started">N</td>
# <td class="left" colspan="19" data-stat="bench_explain">On matchday squad, but did not play</td>
# <td class="left group_start" data-stat="match_report"><a href="/en/matches/a8ab1213/Southampton-Crystal-Palace-December-28-2019-Premier-League">Match Report</a></td>
# <td class="left" csk="4" data-stat="dayofweek">Wed</td>
# <td class="left" data-stat="comp"><a href="/en/comps/9/Premier-League-Stats">Premier League</a></td>
# <td class="left" data-stat="round"><a href="/en/comps/9/Premier-League-Stats">Matchweek 21</a></td>
# <td class="left" data-stat="venue">Away</td>
# <td class="center" csk="0" data-stat="result" style="color:blue; font-weight: bold;">D 1–1</td>
# <td class="left" data-stat="squad"><a href="/en/squads/47c64c55/Crystal-Palace-Stats">Crystal Palace</a></td>
# <td class="left" data-stat="opponent"><a href="/en/squads/1c781004/Norwich-City-Stats">Norwich City</a></td>
# <td class="center" csk="-1" data-stat="game_started">N</td>
# <td class="left" colspan="19" data-stat="bench_explain">On matchday squad, but did not play</td>
# <td class="left group_start" data-stat="match_report"><a href="/en/matches/5bbec2c4/Norwich-City-Crystal-Palace-January-1-2020-Premier-League">Match Report</a></td>
# <td class="left" csk="1" data-stat="dayofweek">Sun</td>
# <td class="left" data-stat="comp"><a href="/en/comps/514/FA-Cup-Stats">FA Cup</a></td>
# <td class="left" data-stat="round"><a href="/en/comps/514/FA-Cup-Stats">Third round</a></td>
# <td class="left" data-stat="venue">Home</td>
# <td class="center" csk="-1" data-stat="result" style="color:red; font-weight: bold;">L 0–1</td>
# <td class="left" data-stat="squad"><a href="/en/squads/47c64c55/Crystal-Palace-Stats">Crystal Palace</a></td>
# <td class="left" data-stat="opponent"><a href="/en/squads/26ab47ee/Derby-County-Stats">Derby County</a></td>
# <td class="center" csk="-1" data-stat="game_started">N</td>
# <td class="left" colspan="19" data-stat="bench_explain">On matchday squad, but did not play</td>
# <td class="left group_start" data-stat="match_report"><a href="/en/matches/03ddae39/Crystal-Palace-Derby-County-January-5-2020-FA-Cup">Match Report</a></td>
# <td class="left" csk="7" data-stat="dayofweek">Sat</td>
# <td class="left" data-stat="comp"><a href="/en/comps/15/League-One-Stats">League One</a></td>
# <td class="left" data-stat="round"><a href="/en/comps/15/League-One-Stats">Matchweek 35</a></td>
# <td class="left" data-stat="venue">Away</td>
# <td class="center" csk="-3" data-stat="result" style="color:red; font-weight: bold;">L 0–3</td>
# <td class="left" data-stat="squad"><a href="/en/squads/654f3ca6/Bristol-Rovers-Stats">Bristol Rovers</a></td>
# <td class="left" data-stat="opponent"><a href="/en/squads/8ef52968/Sunderland-Stats">Sunderland</a></td>
# <td class="center" csk="-1" data-stat="game_started">N</td>
# <td class="left" colspan="19" data-stat="bench_explain">On matchday squad, but did not play</td>
# <td class="left group_start" data-stat="match_report"><a href="/en/matches/74c37492/Sunderland-Bristol-Rovers-February-22-2020-League-One">Match Report</a></td>
# <td class="left" csk="7" data-stat="dayofweek">Sat</td>
# <td class="left" data-stat="comp"><a href="/en/comps/15/League-One-Stats">League One</a></td>
# <td class="left" data-stat="round"><a href="/en/comps/15/League-One-Stats">Matchweek 36</a></td>
# <td class="left" data-stat="venue">Home</td>
# <td class="center" csk="-1" data-stat="result" style="color:red; font-weight: bold;">L 0–1</td>
# <td class="left" data-stat="squad"><a href="/en/squads/654f3ca6/Bristol-Rovers-Stats">Bristol Rovers</a></td>
# <td class="left" data-stat="opponent"><a href="/en/squads/b435dbf5/Shrewsbury-Town-Stats">Shrewsbury</a></td>
# <td class="center" csk="0" data-stat="game_started">N</td>
# <td class="center iz" data-stat="position"></td>
# <td class="right" data-stat="minutes">20</td>
# <td class="right iz group_start" data-stat="goals">0</td>
# <td class="right iz" data-stat="assists">0</td>
# <td class="right iz" data-stat="pens_made">0</td>
# <td class="right iz" data-stat="pens_att">0</td>
# <td class="right iz" data-stat="shots_total">0</td>
# <td class="right iz" data-stat="shots_on_target">0</td>
# <td class="right iz" data-stat="cards_yellow">0</td>
# <td class="right iz" data-stat="cards_red">0</td>
# <td class="right iz" data-stat="fouls">0</td>
# <td class="right" data-stat="fouled">1</td>
# <td class="right iz" data-stat="offsides">0</td>
# <td class="right iz" data-stat="crosses">0</td>
# <td class="right iz" data-stat="tackles_won">0</td>
# <td class="right iz" data-stat="interceptions">0</td>
# <td class="right iz" data-stat="own_goals">0</td>
# <td class="right iz" data-stat="pens_won"></td>
# <td class="right iz" data-stat="pens_conceded"></td>
# <td class="left group_start" data-stat="match_report"><a href="/en/matches/72c65896/Bristol-Rovers-Shrewsbury-Town-February-29-2020-League-One">Match Report</a></td>
# <td class="left" csk="7" data-stat="dayofweek">Sat</td>
# <td class="left" data-stat="comp"><a href="/en/comps/15/League-One-Stats">League One</a></td>
# <td class="left" data-stat="round"><a href="/en/comps/15/League-One-Stats">Matchweek 37</a></td>
# <td class="left" data-stat="venue">Away</td>
# <td class="center" csk="-2" data-stat="result" style="color:red; font-weight: bold;">L 1–3</td>
# <td class="left" data-stat="squad"><a href="/en/squads/654f3ca6/Bristol-Rovers-Stats">Bristol Rovers</a></td>
# <td class="left" data-stat="opponent"><a href="/en/squads/2b9f86b0/Southend-United-Stats">Southend United</a></td>
# <td class="center" csk="1" data-stat="game_started">Y</td>
# <td class="center" data-stat="position">FW</td>
# <td class="right" data-stat="minutes">73</td>
# <td class="right iz group_start" data-stat="goals">0</td>
# <td class="right iz" data-stat="assists">0</td>
# <td class="right iz" data-stat="pens_made">0</td>
# <td class="right iz" data-stat="pens_att">0</td>
# <td class="right" data-stat="shots_total">1</td>
# <td class="right iz" data-stat="shots_on_target">0</td>
# <td class="right iz" data-stat="cards_yellow">0</td>
# <td class="right iz" data-stat="cards_red">0</td>
# <td class="right" data-stat="fouls">1</td>
# <td class="right" data-stat="fouled">1</td>
# <td class="right iz" data-stat="offsides">0</td>
# <td class="right iz" data-stat="crosses">0</td>
# <td class="right" data-stat="tackles_won">1</td>
# <td class="right" data-stat="interceptions">1</td>
# <td class="right iz" data-stat="own_goals">0</td>
# <td class="right iz" data-stat="pens_won"></td>
# <td class="right iz" data-stat="pens_conceded"></td>
# <td class="left group_start" data-stat="match_report"><a href="/en/matches/6b1fac43/Southend-United-Bristol-Rovers-March-7-2020-League-One">Match Report</a></td>
# <td class="left" csk="3" data-stat="dayofweek">Tue</td>
# <td class="left" data-stat="comp"><a href="/en/comps/15/League-One-Stats">League One</a></td>
# <td class="left" data-stat="round"><a href="/en/comps/15/League-One-Stats">Matchweek 18</a></td>
# <td class="left" data-stat="venue">Home</td>
# <td class="center" csk="2" data-stat="result" style="color:green; font-weight: bold;">W 2–0</td>
# <td class="left" data-stat="squad"><a href="/en/squads/654f3ca6/Bristol-Rovers-Stats">Bristol Rovers</a></td>
# <td class="left" data-stat="opponent"><a href="/en/squads/8ef52968/Sunderland-Stats">Sunderland</a></td>
# <td class="center" csk="0" data-stat="game_started">N</td>
# <td class="center iz" data-stat="position"></td>
# <td class="right" data-stat="minutes">11</td>
# <td class="right iz group_start" data-stat="goals">0</td>
# <td class="right iz" data-stat="assists">0</td>
# <td class="right iz" data-stat="pens_made">0</td>
# <td class="right iz" data-stat="pens_att">0</td>
# <td class="right iz" data-stat="shots_total">0</td>
# <td class="right iz" data-stat="shots_on_target">0</td>
# <td class="right iz" data-stat="cards_yellow">0</td>
# <td class="right iz" data-stat="cards_red">0</td>
# <td class="right iz" data-stat="fouls">0</td>
# <td class="right" data-stat="fouled">2</td>
# <td class="right iz" data-stat="offsides">0</td>
# <td class="right iz" data-stat="crosses">0</td>
# <td class="right iz" data-stat="tackles_won">0</td>
# <td class="right" data-stat="interceptions">1</td>
# <td class="right iz" data-stat="own_goals">0</td>
# <td class="right iz" data-stat="pens_won"></td>
# <td class="right iz" data-stat="pens_conceded"></td>
# <td class="left group_start" data-stat="match_report"><a href="/en/matches/7073724f/Bristol-Rovers-Sunderland-March-10-2020-League-One">Match Report</a></td>
# <td class="left" csk="2" data-stat="dayofweek">Mon</td>
# <td class="left" data-stat="comp"><a href="/en/comps/9/Premier-League-Stats">Premier League</a></td>
# <td class="left" data-stat="round"><a href="/en/comps/9/Premier-League-Stats">Matchweek 37</a></td>
# <td class="left" data-stat="venue">Away</td>
# <td class="center" csk="-2" data-stat="result" style="color:red; font-weight: bold;">L 0–2</td>
# <td class="left" data-stat="squad"><a href="/en/squads/47c64c55/Crystal-Palace-Stats">Crystal Palace</a></td>
# <td class="left" data-stat="opponent"><a href="/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats">Wolves</a></td>
# <td class="center" csk="-1" data-stat="game_started">N</td>
# <td class="left" colspan="19" data-stat="bench_explain">On matchday squad, but did not play</td>
# <td class="left group_start" data-stat="match_report"><a href="/en/matches/70598e52/Wolverhampton-Wanderers-Crystal-Palace-July-20-2020-Premier-League">Match Report</a></td>
# <td class="left" csk="1" data-stat="dayofweek">Sun</td>
# <td class="left" data-stat="comp"><a href="/en/comps/9/Premier-League-Stats">Premier League</a></td>
# <td class="left" data-stat="round"><a href="/en/comps/9/Premier-League-Stats">Matchweek 38</a></td>
# <td class="left" data-stat="venue">Home</td>
# <td class="center" csk="0" data-stat="result" style="color:blue; font-weight: bold;">D 1–1</td>
# <td class="left" data-stat="squad"><a href="/en/squads/47c64c55/Crystal-Palace-Stats">Crystal Palace</a></td>
# <td class="left" data-stat="opponent"><a href="/en/squads/361ca564/Tottenham-Hotspur-Stats">Tottenham</a></td>
# <td class="center" csk="-1" data-stat="game_started">N</td>
# <td class="left" colspan="19" data-stat="bench_explain">On matchday squad, but did not play</td>
# <td class="left group_start" data-stat="match_report"><a href="/en/matches/61616d45/Crystal-Palace-Tottenham-Hotspur-July-26-2020-Premier-League">Match Report</a></td>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-721012d78af4> in <module>
#      16                 response2 = requests.get(url2)
#      17                 #print(url2)
# ---> 18                 soup2 = BeautifulSoup(response2.content, 'html.parser')
#      19                 table2 = soup2.find_all('table', id = 'matchlogs_all')
#      20                 table2 = table2[0]
#
# ~\.conda\envs\aifml\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     343             self.reset()
#     344             try:
# --> 345                 self._feed()
#     346                 success = True
#     347                 break
#
# ~\.conda\envs\aifml\lib\site-packages\bs4\__init__.py in _feed(self)
#     429         self.builder.reset()
#     430
# --> 431         self.builder.feed(self.markup)
#     432         # Close out any unfinished strings and close all the open tags.
#     433         self.endData()
#
# ~\.conda\envs\aifml\lib\site-packages\bs4\builder\_htmlparser.py in feed(self, markup)
#     375         parser.soup = self.soup
#     376         try:
# --> 377             parser.feed(markup)
#     378             parser.close()
#     379         except HTMLParseError as e:
#
# ~\.conda\envs\aifml\lib\html\parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# ~\.conda\envs\aifml\lib\html\parser.py in goahead(self, end)
#     169             if startswith('<', i):
#     170                 if starttagopen.match(rawdata, i): # < + letter
# --> 171                     k = self.parse_starttag(i)
#     172                 elif startswith("</", i):
#     173                     k = self.parse_endtag(i)
#
# ~\.conda\envs\aifml\lib\html\parser.py in parse_starttag(self, i)
#     343             self.handle_startendtag(tag, attrs)
#     344         else:
# --> 345             self.handle_starttag(tag, attrs)
#     346             if tag in self.CDATA_CONTENT_ELEMENTS:
#     347                 self.set_cdata_mode(tag)
#
# ~\.conda\envs\aifml\lib\site-packages\bs4\builder\_htmlparser.py in handle_starttag(self, name, attrs, handle_empty_element)
#     149         #print("START", name)
#     150         sourceline, sourcepos = self.getpos()
# --> 151         tag = self.soup.handle_starttag(
#     152             name, None, None, attr_dict, sourceline=sourceline,
#     153             sourcepos=sourcepos
#
# ~\.conda\envs\aifml\lib\site-packages\bs4\__init__.py in handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos)
#     687             return None
#     688
# --> 689         tag = self.element_classes.get(Tag, Tag)(
#     690             self, self.builder, name, namespace, nsprefix, attrs,
#     691             self.currentTag, self._most_recent_element,
#
# ~\.conda\envs\aifml\lib\site-packages\bs4\element.py in __init__(self, parser, builder, name, namespace, prefix, attrs, parent, previous, is_xml, sourceline, sourcepos, can_be_empty_element, cdata_list_attributes, preserve_whitespace_tags)
#    1097             # We don't actually store the parser object: that lets extracted
#    1098             # chunks be garbage-collected.
# -> 1099             self.parser_class = parser.__class__
#    1100         if name is None:
#    1101             raise ValueError("No value provided for new tag's name.")
#
# KeyboardInterrupt:
